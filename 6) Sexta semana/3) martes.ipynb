# %%
import pandas as pd
s = pd.Series([10, 20, 30, 40, 50],index=['a', 'b', 'c', 'd', 'e'])
s2 = pd.Series([100, 200, 300, 400, 500],index=['a', 'b', 'c', 'd', 'e'])

data = {"one":s,"two":s2}

pd.DataFrame(data)
# This code creates a pandas DataFrame from two Series objects. Each Series
# represents a column in the DataFrame, with the specified indices serving 
# as the row labels. The resulting DataFrame will have two columns 
# named "one" and "two", containing the values from the respective Series.
# Out:
#    one  two
# a   10  100
# b   20  200
# c   30  300
# d   40  400
# e   50  500

# %%
import pandas as pd 

d ={"col1": [1,2,3,4,5],
    "col2": [10,20,30,40,50]}

df = pd.DataFrame(d)
print(df)
# This code creates a pandas DataFrame from a dictionary where the keys
# represent column names and the values are lists of data for each column.

df = df.rename(columns={"col1":"primera_columna","col2":"segunda_columna"})
print(df)

df.rename(index={0:"primera_fila",1:"segunda_fila",2:"tercera_fila",3:"cuarta_fila",4:"quinta_fila"})
# This code renames the columns of the DataFrame to "primera_columna" and "segunda_columna".
# It also renames the index labels to "primera_fila", "segunda_fila", "tercera_fila", "cuarta_fila", and "quinta_fila".
# Out:
#    col1  col2
# 0     1    10
# 1     2    20
# 2     3    30
# 3     4    40
# 4     5    50
#    primera_columna  segunda_columna
# 0                1               10
# 1                2               20
# 2                3               30
# 3                4               40
# 4                5               50
#               primera_columna  segunda_columna
# primera_fila                1               10
# segunda_fila                2               20
# tercera_fila                3               30
# cuarta_fila                 4               40
# quinta_fila                 5               50

# %%
# Importamos la librería 'os' (Operating System)
import os

# Imprime el "Directorio de Trabajo Actual" (Current Working Directory)
print(os.getcwd())
# Out:
# c:\todo\samsung curso\Primera Parte\Samsung-Innovention-Campus\6) Sexta semana

# %%
import pandas as pd

# La ruta correcta es:
ruta_del_archivo = "./Notebooks and data-20251021/data/titanic/test.csv"

df = pd.read_csv(ruta_del_archivo)
print(df.head())
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.head(-1)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1304       3                Henriksson, Miss. Jenny Lovisa
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
df.shape
#shape es un atributo, no una función, por lo que no debe llevar paréntesis.
#un atributo proporciona información sobre el objeto, mientras que una función realiza una acción o cálculo.
# Out:
# (418, 11)

# %%
s  = pd.Series([10, 20, 30, 40, 50],index=['a', 'b', 'c', 'd', 'e'])

#usar suma
s.sum()
# Out:
# np.int64(150)

# %%
df = pd.read_csv("./Notebooks and data-20251021/data/titanic/train.csv")
#sobrevivio 0 = si, no = 1
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe()
#percentiles 25%, 50%, 75%
#significan que el 25% de los datos están por debajo del valor en el percentil 25,
#el 50% de los datos están por debajo del valor en el percentil 50 (que es la mediana),
#y el 75% de los datos están por debajo del valor en el percentil 75.
#XDDDD
#pero en palabras simples, los percentiles dividen un conjunto de datos en 100 partes iguales,
#lo que ayuda a entender la distribución y dispersión de los datos.
#XDDDD
#pero en palabras mas sencillas el percentil 25 es el valor por debajo del cual se encuentra 
#el 25% de los datos,
#el percentil 50 es el valor por debajo del cual se encuentra el 50% de los datos (la mediana),
#y el percentil 75 es el valor por debajo del cual se encuentra el 75% de los datos.
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df = pd.read_csv("./Notebooks and data-20251021/data/titanic/train.csv",header=2)
df.describe()
# Out:
#                 2           1         1.1          38         1.2           0  \
# count  889.000000  889.000000  889.000000  712.000000  889.000000  889.000000
# mean   447.000000    0.383577    2.309336   29.698272    0.521935    0.382452
# std    256.776492    0.486531    0.835537   14.540716    1.103752    0.806761
# min      3.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    225.000000    0.000000    2.000000   20.000000    0.000000    0.000000
# 50%    447.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    669.000000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    891.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#           71.2833
# count  889.000000
# mean    32.188319
# std     49.725017
# min      0.000000
# 25%      7.925000
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
#df = pd.read_csv("data/titanic/train.csv",header=2)
df = pd.read_csv("./Notebooks and data-20251021/data/titanic/train.csv",header=2)
df.head(2)
# Out:
#    2  1  1.1 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  \
# 0  3  1    3                             Heikkinen, Miss. Laina   female
# 1  4  1    1       Futrelle, Mrs. Jacques Heath (Lily May Peel)   female
#
#      38  1.2  0          PC 17599  71.2833   C85  C
# 0  26.0    0  0  STON/O2. 3101282    7.925   NaN  S
# 1  35.0    1  0            113803   53.100  C123  S

# %%
import pandas as pd 

ruta_excel = "./Notebooks and data-20251021/data/nba/Players.xls"

df = pd.read_excel(ruta_excel, sheet_name = 0, header = 0)

# Comprobamos
df.head()
# Out:
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state
# 0               Indiana University  1918.0          NaN         NaN
# 1           University of Kentucky  1921.0     Yorktown     Indiana
# 2         University of Notre Dame  1924.0          NaN         NaN
# 3  North Carolina State University  1925.0          NaN         NaN
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky

# %%
import pandas as pd
import matplotlib.pyplot as plt

#El comando pd.read_json() necesita que le especifiques la "orientación" (orient) 
# de cómo está estructurado el archivo JSON . Además, el nombre del archivo en 
# el ejemplo es universities_ranking.json (en plural
ruta_json = "./Notebooks and data-20251021/data/World University Rankings 2021/universities_ranking.json"

# Añadimos orient='records' como se muestra en el ejemplo
df = pd.read_json(ruta_json, orient='records')

df.head()
# Out:
#    ranking                                  title        location  \
# 0        1                   University of Oxford  United Kingdom
# 1        2                    Stanford University   United States
# 2        3                     Harvard University   United States
# 3        4     California Institute of Technology   United States
# 4        5  Massachusetts Institute of Technology   United States
#
#   number students  students staff ratio perc intl students gender ratio
# 0          20,774                  11.1                41%      46 : 54
# 1          16,223                   7.4                23%      44 : 56
# 2          21,261                   9.3                25%      49 : 51
# 3           2,238                   6.3                33%      36 : 64
# 4          11,276                   8.4                34%      39 : 61

# %%
import pandas as pd
import matplotlib.pyplot as plt

#El comando pd.read_json() necesita que le especifiques la "orientación" (orient) 
# de cómo está estructurado el archivo JSON . Además, el nombre del archivo en 
# el ejemplo es universities_ranking.json (en plural
ruta_json = "./Notebooks and data-20251021/data/World University Rankings 2021/universities_ranking.json"

# Añadimos orient='records' como se muestra en el ejemplo
df = pd.read_json(ruta_json, orient='records')
#usamos drop
# Out:
# <bound method Series.drop of a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64>

# %%
import pandas as pd
import matplotlib.pyplot as plt

ruta_json = "./Notebooks and data-20251021/data/World University Rankings 2021/universities_ranking.json"

# Añadimos orient='records' como se muestra en el ejemplo
df = pd.read_json(ruta_json, orient='records')

df.head()
print("postion fila 1, columna 1:")
print(df.iloc[1,1])

print("columnas 2,3,4 de la fila 1:")
df.iloc[1,[2,3,4]]
#comprobamos con loc
# Usamos .loc[] pero con los nombres de las columnas
print("Columnas 'location', 'number students', 'students staff ratio' de la fila '1':")
df.loc[1, ['location', 'number students', 'students staff ratio']]
# Out:
# postion fila 1, columna 1:
# Stanford University
# columnas 2,3,4 de la fila 1:
# Columnas 'location', 'number students', 'students staff ratio' de la fila '1':
# location                United States
# number students                16,223
# students staff ratio              7.4
# Name: 1, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Añadimos la carpeta "spotify/" a la ruta
# La estructura es: .../data/spotify/nombre_del_archivo.csv
ruta_spotify = "./Notebooks and data-20251021/data/spotify/spotify_global_2019_most_streamed_tracks_audio_features.csv"

song = pd.read_csv(ruta_spotify)


song.head()
# Out:
#   Country  Rank                Track_id     Streams        Track Name  \
# 0  global   1.0  25sgk305KZfyuqVBQIahim  1166185736  Sweet but Psycho
# 1  global   2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787           bad guy
# 2  global   3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044           7 rings
# 3  global   4.0  1rgnBhdG2JDFTbYkYRZAku   764208309      Dance Monkey
# 4  global   5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359          Señorita
#
#           Artist                                                URL  \
# 0        Ava Max  https://open.spotify.com/track/25sgk305KZfyuqV...
# 1  Billie Eilish  https://open.spotify.com/track/2Fxmhks0bxGSBdJ...
# 2  Ariana Grande  https://open.spotify.com/track/6ocbgoVGwYJhOv1...
# 3    Tones and I  https://open.spotify.com/track/1rgnBhdG2JDFTbY...
# 4   Shawn Mendes  https://open.spotify.com/track/6v3KW9xbzN5yKLt...
#
#    acousticness  danceability  energy  ...  valence    tempo  time_signature  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Añadimos la carpeta "spotify/" a la ruta
# La estructura es: .../data/spotify/nombre_del_archivo.csv
ruta_spotify = "./Notebooks and data-20251021/data/spotify/spotify_global_2019_most_streamed_tracks_audio_features.csv"

song = pd.read_csv(ruta_spotify)
# Paso 2: Seleccionar solo las columnas necesarias
df = song[["Rank", "Artist", "Track Name", "Artist_popularity", "Streams", "tempo", "danceability", "energy"]]

# Comprobar el nuevo DataFrame 'df'
df.head()
# Out:
#    Rank         Artist        Track Name  Artist_popularity     Streams  \
# 0   1.0        Ava Max  Sweet but Psycho                 87  1166185736
# 1   2.0  Billie Eilish           bad guy                 98  1052358787
# 2   3.0  Ariana Grande           7 rings                 97   789094044
# 3   4.0    Tones and I      Dance Monkey                 92   764208309
# 4   5.0   Shawn Mendes          Señorita                 94   763064359
#
#      tempo  danceability  energy
# 0  133.002         0.719   0.704
# 1  135.128         0.701   0.425
# 2  140.048         0.778   0.317
# 3   98.078         0.825   0.593
# 4  116.967         0.759   0.548

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Añadimos la carpeta "spotify/" a la ruta
# La estructura es: .../data/spotify/nombre_del_archivo.csv
ruta_spotify = "./Notebooks and data-20251021/data/spotify/spotify_global_2019_most_streamed_tracks_audio_features.csv"

song = pd.read_csv(ruta_spotify)
# Paso 2: Seleccionar solo las columnas necesarias
df = song[["Rank", "Artist", "Track Name", "Artist_popularity", "Streams", "tempo", "danceability", "energy"]]

# Comprobar el nuevo DataFrame 'df'
df.head()

pop_song = df[df['Artist_popularity'] >= 100]

# Comprobamos el resultado (mostramos las primeras filas del nuevo DataFrame)
pop_song.head()
# Out:
#     Rank       Artist                   Track Name  Artist_popularity  \
# 9   10.0  Post Malone                         Wow.                100
# 13  14.0  Post Malone  Goodbyes (Feat. Young Thug)                100
# 25  26.0  Post Malone                      Circles                100
# 31  32.0  Post Malone                   Better Now                100
# 33  34.0  Post Malone   rockstar (feat. 21 Savage)                100
#
#       Streams    tempo  danceability  energy
# 9   615519053   99.947         0.833   0.539
# 13  501130662  150.231         0.580   0.653
# 25  428712946  120.042         0.695   0.762
# 31  405953336  145.038         0.680   0.578
# 33  395449434  159.801         0.585   0.520

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Añadimos la carpeta "spotify/" a la ruta
# La estructura es: .../data/spotify/nombre_del_archivo.csv
ruta_spotify = "./Notebooks and data-20251021/data/spotify/spotify_global_2019_most_streamed_tracks_audio_features.csv"

song = pd.read_csv(ruta_spotify)
# Paso 2: Seleccionar solo las columnas necesarias
df = song[["Rank", "Artist", "Track Name", "Artist_popularity", "Streams", "tempo", "danceability", "energy"]]

# Comprobar el nuevo DataFrame 'df'
df.head()

pop_song = df[df['Artist_popularity'] >= 100]

# Comprobamos el resultado (mostramos las primeras filas del nuevo DataFrame)
pop_song.head()

x = df['energy']
y = df['Rank']
plt.scatter(x, y,color='red',alpha=0.5)
plt.xlabel('Energy')
plt.ylabel('Rank')
plt.title('Energy vs Rank')
plt.show()
